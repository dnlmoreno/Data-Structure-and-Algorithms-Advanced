# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tamaños = pd.read_csv('../Resultados/Tamaños_medianos_datos/Experimentacion_busquedas_tamanios.csv', sep = ';')
posiciones = pd.read_csv('../Resultados/Tamaños_medianos_datos/Experimentacion_busquedas_posicion.csv', sep = ';')

# %%
tamaños
# Out:
#    Tamaños  Tiempo_búsqueda_lineal  Tiempo_búsqueda_binaria  \
# 0      100            7.859330e+02                  89.9526
# 1    10000            8.204860e+04                 143.2840
# 2    50000            3.955510e+05                 202.4250
# 3   100000            8.130550e+05                 278.5470
# 4   300000            2.335570e+06                 484.5220
# 5   500000            3.934300e+06                 701.1010
# 6   800000            6.462910e+06                1153.3000
# 7  1000000            8.028940e+06                1105.8900
# 8  1500000            1.193180e+07                1587.8400
# 9  2000000            1.567890e+07                1361.0400
#
#    Tiempo_búsqueda_doblada
# 0                  147.487
# 1                  225.730
# 2                  465.154
# 3                  949.700
# 4                 1622.640
# 5                 2220.700
# 6                 2918.700
# 7                 2807.450
# 8                 2858.810
# ...

# %%
col0_tam = tamaños['Tamaños']
col1_tam = tamaños['Tiempo_búsqueda_lineal']
col2_tam = tamaños['Tiempo_búsqueda_binaria']
col3_tam = tamaños['Tiempo_búsqueda_doblada']

# %%
# Tamaño especial para graficar la busqueda lineal
tamaños_especial = tamaños[tamaños.Tamaños<500]
col0_tam_esp = tamaños_especial['Tamaños']
col1_tam_esp = tamaños_especial['Tiempo_búsqueda_lineal']

# %%
posiciones
# Out:
#    Posición  Tiempo_búsqueda_lineal  Tiempo_búsqueda_binaria  \
# 0    200000            1.496420e+06                 594.3680
# 1    400000            3.053270e+06                 943.1080
# 2    600000            4.422360e+06                 751.8860
# 3    800000            5.914260e+06                 921.3650
# 4   1000000            7.280410e+06                  50.1741
# 5   1200000            8.760820e+06                1518.7400
# 6   1400000            1.023260e+07                1785.2400
# 7   1600000            1.173890e+07                1295.5900
# 8   1800000            1.323940e+07                1486.9900
# 9   2000000            3.834680e+01                 186.7130
#
#    Tiempo_búsqueda_doblada
# 0                  803.229
# 1                 1547.210
# 2                 1399.840
# 3                 1844.180
# 4                 1699.890
# 5                 2363.080
# 6                 2229.820
# 7                 2202.290
# 8                 2201.260
# ...

# %%
col0_pos = posiciones['Posición']
col1_pos = posiciones['Tiempo_búsqueda_lineal']
col2_pos = posiciones['Tiempo_búsqueda_binaria']
col3_pos = posiciones['Tiempo_búsqueda_doblada']

# %%
# Tamaño especial para graficar la busqueda lineal
posiciones_especial = posiciones[posiciones.Posición<500]
col0_tam_esp = posiciones_especial['Posición']
col1_tam_esp = posiciones_especial['Tiempo_búsqueda_lineal']

# %%
''' Grafico que no da información visual clara '''

fig, ax1 = plt.subplots(figsize=(10,7))

ax1.set_xlabel('Tamaño de la entrada', fontsize='15', labelpad=13)
ax1.set_ylabel('Nanosegundos', fontsize='15', labelpad=14)
#ax1.plot(col0_tam_esp, col1_tam_esp, marker="o", color= "c", label='Lineal')
ax1.plot(col0_tam, col2_tam, marker="*", color= "y", label='Búsqueda binaria')
ax1.plot(col0_tam, col3_tam, marker="^", color= "tab:purple", label='Búsqueda doblada')
ax1.tick_params(axis='y')

plt.xticks(fontsize = 13)
plt.yticks(size = 13)

legend = plt.legend(loc='upper left', shadow=True, fontsize='15')
legend.get_frame().set_facecolor('white')

#plt.savefig("Grafico de inserciones user_id.png")
plt.show()

# %%
fig, (ax, ax2) = plt.subplots(2, 1, sharex=True, figsize=(11,8))

''' plot the same data on both axes '''
# Parte de abajo del grafico
ax2.plot(col0_tam, col1_tam, marker="o", color= "c", label='Búsqueda lineal', linewidth=2.5, markersize=7)
ax2.plot(col0_tam, col2_tam, marker="o", color= "y", label='Búsqueda binaria', linewidth=2.5, markersize=7)
ax2.plot(col0_tam, col3_tam, marker="o", color= "tab:purple", label='Búsqueda doblada', linewidth=2.5, markersize=7)

# Parte de arriba del grafico
ax.plot(col0_tam, col1_tam, marker="o", color= "c", label='Búsqueda lineal', linewidth=2.5, markersize=7)
#ax.plot(col0_tam, col2_tam, marker="o", color= "y", label='Búsqueda binaria', linewidth=2.5, markersize=7)
#ax.plot(col0_tam, col3_tam, marker="o", color= "tab:purple", label='Búsqueda doblada', linewidth=2.5, markersize=7)

# zoom-in / limit the view to different portions of the data
ax.set_ylim(3840.79, 14713000)  # outliers only
ax2.set_ylim(0, 2398.63)  # most of the data

# hide the spines between ax and ax2
ax.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax.xaxis.tick_top()
ax.tick_params(labeltop=False)  # don't put tick labels at the top
ax2.xaxis.tick_bottom()

## Agranda los ticks de los ejes x e y con un grafico con ejes broke
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(15) 
plt.xticks(fontsize = 15)
plt.yticks(size = 15)

## Agranda tamaño del 1e6
ax2.xaxis.get_offset_text().set_fontsize(20)
ax2.xaxis.get_offset_text().set_x(1.05)

ax2.set_xlabel('Tamaños de la entrada', fontsize='20', labelpad=13)
ax2.set_ylabel('Nanosegundos', fontsize='20')
ax2.yaxis.set_label_coords(0.055, 0.5, transform=fig.transFigure)

ax.legend(loc='upper left', shadow=True, fontsize='15')

d = .015  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((-d, +d), (-d, +d), **kwargs)        # top-left diagonal
ax.plot((1 - d, 1 + d), (-d, +d), **kwargs)  # top-right diagonal

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)  # bottom-left diagonal
ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)  # bottom-right diagonal

plt.savefig("Grafico_tamaños.png", bbox_inches='tight')
plt.show()

# %%
fig, (ax, ax2) = plt.subplots(2, 1, sharex=True, figsize=(11,8))

''' plot the same data on both axes '''
# Parte de abajo del grafico
ax2.plot(col0_pos, col1_pos, marker="o", color= "c", label='Búsqueda lineal', linewidth=2.5, markersize=7)
ax2.plot(col0_pos, col2_pos, marker="o", color= "y", label='Búsqueda binaria', linewidth=2.5, markersize=7)
ax2.plot(col0_pos, col3_pos, marker="o", color= "tab:purple", label='Búsqueda doblada', linewidth=2.5, markersize=7)

# Parte de arriba del grafico
ax.plot(col0_pos, col1_pos, marker="o", color= "c", label='Búsqueda lineal', linewidth=2.5, markersize=7)
ax.plot(col0_pos, col2_pos, marker="o", color= "y", label='Búsqueda binaria', linewidth=2.5, markersize=7)
ax.plot(col0_pos, col3_pos, marker="o", color= "tab:purple", label='Búsqueda doblada', linewidth=2.5, markersize=7)

# zoom-in / limit the view to different portions of the data
ax.set_ylim(1038270, 15966400)  # outliers only
ax2.set_ylim(0, 3098.63)  # most of the data

# hide the spines between ax and ax2
ax.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax.xaxis.tick_top()
ax.tick_params(labeltop=False)  # don't put tick labels at the top
ax2.xaxis.tick_bottom()

## Agranda los ticks de los ejes x e y con un grafico con ejes broke
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(15) 
plt.xticks(fontsize = 15)
plt.yticks(size = 15)

## Agranda tamaño del 1e6 del eje x
ax2.xaxis.get_offset_text().set_fontsize(20)
ax2.xaxis.get_offset_text().set_x(1.05)

## Agranda tamaño del 1e6 del eje y
ax.yaxis.get_offset_text().set_fontsize(20)
ax.yaxis.get_offset_text().set_x(-0.03)

ax2.set_xlabel('Posición elemento buscado', fontsize='20', labelpad=13)
ax2.set_ylabel('Nanosegundos', fontsize='20')
ax2.yaxis.set_label_coords(0.055, 0.5, transform=fig.transFigure)

ax.legend(loc='upper left', shadow=True, fontsize='15')

d = .015  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((-d, +d), (-d, +d), **kwargs)        # top-left diagonal
ax.plot((1 - d, 1 + d), (-d, +d), **kwargs)  # top-right diagonal

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)  # bottom-left diagonal
ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)  # bottom-right diagonal

plt.savefig("Grafico_posicion.png", bbox_inches='tight')
plt.show()
